# %%
from scipy import array, arange, sqrt,exp
from pylab import plot, show, xlabel, ylabel

xo=1
n=100 #numero de pasos 
x=[]
x.append (xo)
for i in range(100):
    xo= 2-exp(-xo)
    x.append(xo)
    
print (x[len(x)-1])
plot(x,'g')
show()
# Out:
# 1.8414056604369606

# %%
from scipy import array, arange, sqrt,exp
from pylab import plot, show, xlabel, ylabel
xo=0.5
n=100 #numero de pasos 
x=[]
x.append (xo)
for i in range(100):
    xo= exp(1- pow(xo,2))
    x.append(xo)
    
print (x[len(x)-1])
plot(x)
show()
# Out:
# 0.0016799111166579221

# %%
from scipy import array, arange, sqrt,exp,log
from pylab import plot, show, xlabel, ylabel
xo=0.5
n=100 #numero de pasos 
x=[]
x.append (xo)
for i in range(100):
    xo= sqrt(1-log(xo))
    x.append(xo)
    
print (x[len(x)-1])
plot(x,'r')
show()
# Out:
# 1.0

# %%
from scipy import array, arange, sqrt,exp,log,sin
from pylab import plot, show, xlabel, ylabel
xo=0.5
n=100 #numero de pasos 
x=[]
x.append (xo)
for i in range(100):
    xo= pow(xo,2)+sin(2*xo)
    x.append(xo)
    
print (x[len(x)-1])
plot(x,'m')
show()
# Out:
# nan
# /home/usuario/.local/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in double_scalars
#
# /home/usuario/.local/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in sin

# %%
from scipy import array, arange, sqrt,exp,log,sin
from pylab import plot, show, xlabel, ylabel
from math import *
xo=0.5
n=100 #numero de pasos 
x=[]
x.append (xo)
for i in range(100):
    xo= 0.5*(asin(xo-xo**2))
    x.append(xo)
    
print (x[len(x)-1])
plot(x,'c')
show()
# Out:
# 1.5661883104263938e-31
